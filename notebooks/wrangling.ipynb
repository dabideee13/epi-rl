# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
path = lambda directory, filename: Path.joinpath(Path.cwd().parent, 'data/processed', directory, filename)

# %%
actions = pd.read_csv(path('actions', 'actions_seir.csv'), header=None).values.flatten()

# %%
rewards = pd.read_csv(path('rewards', 'rewards_seir.csv'), header=None).values.flatten()

# %%
states = pd.read_csv(path('states', 'states_seir.csv'), header=None).values.flatten()

# %%
states
# Out:
# array(['[3.42180e+04 1.07188e+05 1.68098e+05 1.16520e+04 3.42180e-02 1.07188e-01\n 1.68098e-01 1.16520e-02 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00\n 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 2.00000e+00]',
#        '[3.4217312e+04 1.0718607e+05 1.6809531e+05 1.1652113e+04 1.8397470e+00\n 6.5055823e-01 3.0508637e-01 6.7664313e-01 0.0000000e+00 1.0906699e+00\n 7.4491262e-01 1.3846478e-01 1.2135968e+00 1.7299304e+00 2.8099461e+00\n 6.1045164e-01 2.0000000e+00]',
#        '[3.42034883e+04 1.07144516e+05 1.68073922e+05 1.16515723e+04\n 1.94909298e+00 9.90837383e+00 8.81421375e+00 0.00000000e+00\n 4.13808489e+00 1.02967615e+01 7.70378494e+00 0.00000000e+00\n 1.08656702e+01 2.48189354e+01 9.56450176e+00 3.51288223e+00\n 2.00000000e+00]',
# ...
